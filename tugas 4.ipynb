# %%
a = 'saya'
jajan = 20000

if (jajan <= 30000):
    keterangan = 'jajan cukup'
else:
    keterangan = 'jajan berlebih'
print (a,'jajan hari ini sebesar', jajan, keterangan)
# Out:
# saya jajan hari ini sebesar 20000 jajan cukup

# %%
a = 'saya'
jambelajar = '9 malam'

if (jambelajar > '9 malam'):
    keterangan = 'belajar cukup'
else:
    keterangan = 'belajar tidak cukup'
print (a,'belajar jam', jambelajar, keterangan)
# Out:
# saya belajar jam 9 malam belajar tidak cukup

# %%
a = 'faisya'
belanja = 46000

if (belanja == 50000):
    keterangan = 'belanjan di minimarket'
elif (belanja >= 45000):
    keterangan = 'belanja di alfamart'
else:
    keterangan = 'belanja di toko'
print ('pelanggan',a, 'belanja anda Rp.', belanja, keterangan)
# Out:
# pelanggan faisya belanja anda Rp. 46000 belanja di alfamart

# %%
nama = 'Aliffaisya Fiana'
kelas = 'SI03'
nim = '0110123187'
matkul = 'ddp'
nilai = 85

if (nilai > 90):
    keterangan = 'grade A'
elif (nilai > 80):
    keterangan = 'grade B'
elif (nilai > 70 ):
    keterangan = 'grade C'
else:
    keterangan = 'grade D'
print(nama,kelas,nim, 'Grade Anda pada matkul', matkul, 'adalah',keterangan )
# Out:
# Aliffaisya Fiana SI03 0110123187 Grade Anda pada matkul ddp adalah grade B
