# %%
print("Nama saya: Aliffaisya fiana")
print("Nim: 0110123187")
print("Kelas: SI 03")
print("Alamat: lenteng agung")
# Out:
# Nama saya: Aliffaisya fiana
# Nim: 0110123187
# Kelas: SI 03
# Alamat: lenteng agung

# %%
print("Nama teman: fatimah Ramatias")
print("Nim: 0110123063")
print("Kelas: SI03")
print("Alamat: Gunung Putri")
# Out:
# Nama teman: fatimah Ramatias
# Nim: 0110123063
# Kelas: SI03
# Alamat: Gunung Putri

# %%
print(5+3)
# Out:
# 8

# %%
bilangan1 = 5
bilangan2 = 3
hasil = 8
print(f"jumlah dari bilangan di atas adalah {hasil}")
# Out:
# jumlah dari bilangan di atas adalah 8

# %%
print(7-2)
# Out:
# 5

# %%
print(5*3)
# Out:
# 15

# %%
print(10/2)
# Out:
# 5.0

# %%
namasaya = "Aliffaisya"
nim = "0110123187"
kelas = "si03"
notelp = "085281990527"
alamat = '''jl.hj shibi lenteng agung'''

print(namasaya)
print(nim)
print(kelas)
print(notelp)
print(alamat)
# Out:
# Aliffaisya
# 0110123187
# si03
# 085281990527
# jl.hj shibi lenteng agung

# %%
namatemansaya = "fatimah"
nimnya = "0110123063"
kelas = "si03"
alamat = '''gunung putri'''
notelp = "081808938962"

print(namatemansaya)
print(nimnya)
print(kelas)
print(alamat)
print(notelp)
# Out:
# fatimah
# 0110123063
# si03
# gunung putri
# 081808938962

# %%
tinggi_badan = 156

tinggi_badan_ideal = tinggi_badan - 100
print(f"berat badan saya adalah : {tinggi_badan_ideal}")
# Out:
# berat badan saya adalah : 56

# %%
celcius = 27
fahreinheit = (celcius * 9/5) + 32

print(f'fahreinheit dari 27 celcius adalah : {fahreinheit}')
# Out:
# fahreinheit dari 27 celcius adalah : 80.6

# %%
pi = 22/7
jarijari = 14
tinggi = 7
luas_permukaan = 2 * 22/7 * jarijari * (jarijari + tinggi)
keliling_alas = 2 * 22/7 * jarijari

print(f"luas permukaan tabung : {luas_permukaan:.2f} satuan luas")
print(f"keliling alas tabung : {keliling_alas:.2f} satuan panjang")
# Out:
# luas permukaan tabung : 1848.00 satuan luas
# keliling alas tabung : 88.00 satuan panjang
